# %%
import pandas as pd
import json

# %%
# Load the JSON file
with open('external_companies.json', 'r') as file:
    data = json.load(file)

# Convert JSON data to pandas DataFrame
df = pd.DataFrame(data)

# Extract the list of countries represented in the DataFrame
countries = df['country'].unique()

# Print the list of countries
print("Countries represented in the data:")
print(countries)
# Out:
# Countries represented in the data:
# ['USA' 'Japan' 'Germany' 'United Kingdom' 'France' 'South Korea'
#  'Switzerland' 'Sweden' 'Israel' 'Australia' 'Canada' 'Netherlands'
#  'Spain' 'Italy']

# %%
cardiff_characters = {
    "Joe MacMillan": {
        "Phone": "+1 512-555-0132",
        "Email": "joe.macmillan@cardiffelectric.com",
        "Title": "Senior Product Manager",
        "Company": "Cardiff Electric",
        "Department": "Product Management",
        "Quote": "The future is not something that happens. It's something you make happen.",
        "Personality Trait": "Charismatic and visionary",
        "Writing Style": "Assertive and visionary, often using motivational and forward-looking language."
    },
    "Gordon Clark": {
        "Phone": "+1 512-555-0198",
        "Email": "gordon.clark@cardiffelectric.com",
        "Title": "Chief Engineer",
        "Company": "Cardiff Electric",
        "Department": "Engineering",
        "Quote": "Sometimes you have to take a leap and build your wings on the way down.",
        "Personality Trait": "Ingenious but often troubled",
        "Writing Style": "Technical and detailed, focuses on precision and technical aspects."
    },
    "Cameron Howe": {
        "Phone": "+1 512-555-0147",
        "Email": "cameron.howe@cardiffelectric.com",
        "Title": "Lead Software Developer",
        "Company": "Cardiff Electric",
        "Department": "Software Development",
        "Quote": "I code, therefore I am.",
        "Personality Trait": "Rebellious and innovative",
        "Writing Style": "Casual and direct, often with a creative and unconventional approach."
    },
    "Donna Clark": {
        "Phone": "+1 512-555-0156",
        "Email": "donna.clark@cardiffelectric.com",
        "Title": "Director of Operations",
        "Company": "Cardiff Electric",
        "Department": "Operations",
        "Quote": "Behind every great product is a team making it happen.",
        "Personality Trait": "Pragmatic and driven",
        "Writing Style": "Clear and structured, often uses analytical and organized language."
    },
    "John Bosworth": {
        "Phone": "+1 512-555-0179",
        "Email": "john.bosworth@cardiffelectric.com",
        "Title": "Vice President of Sales",
        "Company": "Cardiff Electric",
        "Department": "Sales",
        "Quote": "Success is not the result of spontaneous combustion. You must set yourself on fire.",
        "Personality Trait": "Gruff but caring",
        "Writing Style": "Persuasive and straightforward, often aims to motivate and lead."
    }
}

# Example of how to save this dictionary to a JSON file
import json

with open('cardiff_characters.json', 'w') as file:
    json.dump(cardiff_characters, file, indent=4)
