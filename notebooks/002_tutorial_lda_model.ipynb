# %% [markdown]
# # LDA Topic Modeling Tutorial

# %%
# Required to display widgets in Jupyter
import os
import sys

#This will navigate up two levels in the directory structure to the project root directory. 
sys.path.append(os.path.dirname(os.getcwd()))

# Import the necessary widget handling libraries
from IPython.display import display

# Import to minimize warning. 
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

from topicminer import train_lda_model, display_lda
#import pyLDAvis

# %% [markdown]
# ## Build the LDA model

# %%
lda_model_tfidf = train_lda_model(passes=10, num_topics=5, iterations=100)
# Out:
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training LDA Model:   0%|          | 0/9 [00:00<?, ?it/s]/home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training LDA Model:  11%|█         | 1/9 [00:00<00:03,  2.62it/s]/home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training LDA Model:  22%|██▏       | 2/9 [00:00<00:02,  2.61it/s]/home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training LDA Model:  33%|███▎      | 3/9 [00:01<00:02,  2.53it/s]/home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training LDA Model:  44%|████▍     | 4/9 [00:01<00:01,  2.58it/s]/home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training LDA Model:  56%|█████▌    | 5/9 [00:01<00:01,  2.54it/s]/home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training LDA Model:  67%|██████▋   | 6/9 [00:02<00:01,  2.48it/s]/home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training LDA Model:  78%|███████▊  | 7/9 [00:02<00:00,  2.55it/s]/home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training LDA Model:  89%|████████▉ | 8/9 [00:03<00:00,  2.58it/s]/home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/multiprocessing/popen_fork.py:66: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   self.pid = os.fork()
# Training LDA Model: 100%|██████████| 9/9 [00:03<00:00,  2.56it/s]

# %% [markdown]
# ## Make LDA Visualization and Select the Model

# %%
display_lda(lda_model_tfidf)
# Out:
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# /home/aaronnhorvitz/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/joblib/externals/loky/backend/fork_exec.py:38: DeprecationWarning: This process (pid=160742) is multi-threaded, use of fork() may lead to deadlocks in the child.
#   pid = os.fork()
# Output()

# %% [markdown]
# ## Display a Dataframe of the Topics From The Selected Model
