# %% [markdown]
# # LDA Topic Modeling Tutorial

# %%
# Required to display widgets in Jupyter
import os
import sys

#This will navigate up two levels in the directory structure to the root of your project
sys.path.append(os.path.dirname(os.getcwd()))

# Import to minimize warning. 
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

#import topicminer as tm

from topicminer.models.topic_models.lda_model import train_lda_model

# %% [markdown]
# # Create the LDA model object

# %%
lda_model_tfidf = train_lda_model()
