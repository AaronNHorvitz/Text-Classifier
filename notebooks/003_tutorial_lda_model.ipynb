# %% [markdown]
# # LDA Topic Modeling Tutorial

# %%
# Required to display widgets in Jupyter
import os
import sys

#This will navigate up two levels in the directory structure to the project root directory. 
sys.path.append(os.path.dirname(os.getcwd()))

# Import to minimize warning. 
import warnings
#warnings.filterwarnings('ignore', category=DeprecationWarning)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

from topicminer import train_lda_model, display_lda

# %% [markdown]
# # Build the LDA model

# %%
lda_model_tfidf = train_lda_model(passes=10, num_topics=5, iterations=100)
# Out:
# Training LDA Model: 100%|██████████| 9/9 [01:15<00:00,  8.37s/it]

# %% [markdown]
# ## Make LDA Visualization and Select the Model Number Under the Intertopic Distance Map

# %%
display_lda(lda_model_tfidf)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el34986071246552771207208778941123" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el34986071246552771207208778941123_data = {"mdsDat": {"x": [-0.12758587246649172, -0.1579078631707595, 0.03099921038469495, 0.03151286251246909, 0.22298166274008707], "y": [0.14198477113436195, -0.05683583659653486, 0.074238270051977, -0.22133904578846572, 0.06195184119866157], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [11.617758154857473, 37.1770885464074, 30.469883620433, 0.4606803395796401, 20.27458933872249]}, "tinfo": {"Term": ["expense", "dedication", "vacation", "hard", "moment", "gratitude", "milestone", "your", "express", "congratulations", "sales", "legal", "work", "effort", "no", "issue", "thing", "trying", "thrilled", "counsel", "thank", "you", "subject", "compliance", "system", "wanted", "unnoticed", "report", "support", "notice", "dedication", "unnoticed", "contribution", "accomplished", "condolences", "instrumental", "honored", "alongside", "tireless", "testament", "season", "perseverance", "sincere", "appreciation", "refreshed", "genuine", "honor", "exceptional", "often", "mcmillan", "deeply", "legacy", "continuing", "rewarding", "greetings", "gratitude", "demonstrated", "integral", "mid", "heartfelt", "incredible", "passing", "gone", "condolence", "loss", "talented", "accomplishment", "congratulations", "thank", "pleasure", "holiday", "achievement", "acknowledge", "express", "moment", "vacation", "proud", "year", "hard", "milestone", "your", "notice", "thrilled", "effort", "made", "wanted", "work", "collective", "expertise", "personal", "team", "take", "support", "regard", "operations", "reach", "keep", "product", "so", "hey", "actually", "okay", "pretty", "talk", "just", "do", "guy", "though", "anyway", "real", "saying", "maybe", "gon", "na", "yeah", "stoked", "crazy", "bunch", "talking", "wild", "enough", "honestly", "ta", "said", "is", "straight", "whatever", "little", "trying", "developer", "that", "listen", "no", "kind", "very", "howe", "subject", "thing", "got", "and", "but", "stuck", "really", "going", "right", "mean", "what", "feeling", "get", "think", "you", "engberk", "something", "sales", "good", "software", "we", "truly", "lead", "make", "like", "sure", "idea", "it", "let", "hi", "need", "u", "objective", "availability", "relocation", "space", "facing", "conference", "quo", "campaign", "topic", "leverage", "disrupt", "foster", "seize", "logistics", "beneficial", "advancement", "steps", "objectives", "contribute", "vendor", "forefront", "poised", "charge", "discuss", "combined", "venue", "bond", "showcase", "initial", "developing", "metric", "wednesday", "scheduled", "environment", "safety", "pm", "finalize", "develop", "landscape", "computing", "training", "key", "event", "regular", "below", "essential", "planning", "initiative", "meeting", "explore", "strategy", "schedule", "input", "discus", "project", "burris", "social", "believe", "industry", "manager", "area", "operations", "opportunity", "management", "supplier", "pc", "health", "update", "review", "new", "product", "next", "as", "current", "regard", "forward", "best", "team", "request", "please", "department", "halt", "detox", "onboarding", "overflow", "packet", "buffer", "bump", "baby", "inefficient", "stack", "snack", "massive", "biased", "infinite", "lemon", "fragmentation", "fascinating", "screen", "brass", "tack", "politics", "depend", "mvp", "developmen", "forum", "lemonade", "wind", "dance", "cruising", "stepping", "beauty", "considerations", "leap", "text", "brick", "until", "expense", "rectify", "int", "log", "recall", "any", "maintenance", "utmost", "affected", "investigation", "instance", "adhering", "notification", "corrected", "verify", "revealed", "per", "adherence", "restart", "manner", "null", "submission", "logic", "defect", "confidentiality", "primary", "attempting", "applicable", "def", "import", "incident", "resolve", "property", "intellectual", "discrepancy", "unforeseen", "snippet", "legal", "counsel", "compelled", "cause", "prompt", "error", "issue", "policy", "guideline", "report", "pre ...

# %% [markdown]
# ## Display a Dataframe of the Topics From The Selected Model
