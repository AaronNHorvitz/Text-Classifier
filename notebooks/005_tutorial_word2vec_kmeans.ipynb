# %% [markdown]
# # Word2Vec - K-Means Topic Modeling Tutorial

# %%
# Required to display widgets in Jupyter
import os
import sys
import pandas as pd

#This will navigate up two levels in the directory structure to the project root directory. 
sys.path.append(os.path.dirname(os.getcwd()))

#Import to minimize warning. 
import warnings
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

from topicminer import Word2Vec_KMeans_Cat

# %%
pd.options.display.max_rows = 100        #Increases the number of rows displayed without a break in the middle.
pd.options.display.max_columns = 100     #Increases the number of columns displayed without a break in the middle.
pd.set_option('max_colwidth',2000)

# %% [markdown]
# # Summary Explanation of the Word2Vec - Kmeans Algorithm

# %% [markdown]
# Imagine you're organizing a vast collection of scattered notes. First, you want to understand the essence of each note—this is what Word2Vec does. It learns from the context of words, transforming each word into a numerical vector that captures its meaning based on the words around it. Just as you might summarize a note by its key points, Word2Vec summarizes a word by its relationships.
#
# Now, with each note distilled into a core vector, you need to group similar notes together. Enter KMeans, a method that finds common themes. It's like sorting these vectors into buckets where each bucket holds notes that talk about similar things. KMeans decides the buckets by finding the center points that are closest to the most notes, adjusting as it goes to keep the groups as meaningful and distinct as possible.
#
# Together, Word2Vec and KMeans help in tidying up the mess—first by understanding the notes and then by stacking them neatly into groups where each pile makes sense together. This makes navigating through them easier, letting you quickly find the type of note or information you need.

# %% [markdown]
# # Train the Model

# %%
categorizer = Word2Vec_KMeans_Cat(n_clusters=10, num_unique_terms=10)
# Out:
# Workers can be no higher than 8. Resetting to 8.

# %% [markdown]
# # Show Clusters

# %%
categorizer.show_topics()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 categorizer.show_topics()
#
# File ~/dev/work/irs/TopicMiner/topicminer/models/topic_models/word2vec_kmeans.py:89, in Word2Vec_KMeans_Cat.show_topics(self)
#      88 def show_topics(self):
# ---> 89     emails_df, key_terms = self.categorize_documents()
#      90     labels_df = pd.DataFrame.from_dict(key_terms, orient='index')
#      91     labels_df.index.name = 'Cluster'
#
# File ~/dev/work/irs/TopicMiner/topicminer/models/topic_models/word2vec_kmeans.py:58, in Word2Vec_KMeans_Cat.categorize_documents(self)
#      55 self.kmeans = KMeans(n_clusters=self.n_clusters, random_state=0).fit(doc_vectors)
#      57 # Extract top terms
# ---> 58 key_terms = self.extract_key_terms()
#      60 # Map cluster labels to key terms
#      61 cluster_labels = self.kmeans.labels_
#
# File ~/dev/work/irs/TopicMiner/topicminer/models/topic_models/word2vec_kmeans.py:79, in Word2Vec_KMeans_Cat.extract_key_terms(self)
#      77 for i in range(self.n_clusters):
#      78     centroid = centroids[i]
# ---> 79     cos_similarities = cosine_similarity([centroid], np.array([self.document_vector(doc) for doc in self.tokenized_docs]))
#      80     top_docs_indices = np.argsort(cos_similarities[0])[-3:]  # Get indices of the top 3 closest documents
#      81     cluster_terms = []
#
# File ~/dev/work/irs/TopicMiner/topicminer/models/topic_models/word2vec_kmeans.py:142, in Word2Vec_KMeans_Cat.document_vector(self, doc)
#     139 words = [word for word in doc if word in self.model.wv.index_to_key]
#     140 if words:
#     141     # Ensure the vector is of type float64
# --> 142     return np.mean(self.model.wv[words], axis=0).astype(np.float64)
#     143 else:
#     144     return np.zeros(self.vector_size, dtype=np.float64)
#
# File ~/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/gensim/models/keyedvectors.py:405, in KeyedVectors.__getitem__(self, key_or_keys)
#     402 if isinstance(key_or_keys, _KEY_TYPES):
#     403     return self.get_vector(key_or_keys)
# --> 405 return vstack([self.get_vector(key) for key in key_or_keys])
#
# File ~/miniconda3/envs/aaron_dev/lib/python3.12/site-packages/gensim/models/keyedvectors.py:453, in KeyedVectors.get_vector(self, key, norm)
#     450 else:
#     451     result = self.vectors[index]
# --> 453 result.setflags(write=False)  # disallow direct tampering that would invalidate `norms` etc
#     454 return result
#
# KeyboardInterrupt:

# %% [markdown]
# # Show Clusters with Emails

# %%
categorizer.show_clusters_with_emails()

# %% [markdown]
# # Group Emails by Cluster

# %%
categorizer.group_emails_by_cluster()
