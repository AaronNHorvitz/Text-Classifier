# %% [markdown]
# # Add Embedings Tutorial

# %%
# Required to display widgets in Jupyter
import os
import sys

#This will navigate up two levels in the directory structure to the root of your project
sys.path.append(os.path.dirname(os.getcwd()))

# Import to minimize warning. 
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

# Import the necessary widget handling libraries
from IPython.display import display

from topicminer.models.topic_models import add_lda_embedings

# %% [markdown]
# # Add LDA Embedings

# %% [markdown]
# <p>Each document (email) is enhanced with a new field "lda_topics" which consists of topic IDs and their corresponding probability scores indicating the extent to which the document pertains to those topics.</p>
# <p>For instance, "lda_topics": {"0": 0.2552, "2": 0.7342} means that for that particular email, topic 0 constitutes about 25.52% and topic 2 about 73.42% of the thematic content of the email.</p>

# %%
add_lda_embedings()
