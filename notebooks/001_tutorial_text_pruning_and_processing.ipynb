# %% [markdown]
# # Text Pruning and Processing Tutorial

# %%
# Required to display widgets in Jupyter
import os
import sys

#This will navigate up two levels in the directory structure to the root of your project
sys.path.append(os.path.dirname(os.getcwd()))

# Import to minimize warning. 
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

# Import the necessary widget handling libraries
from IPython.display import display

# Import your custom widget
from topicminer.utils.widgets import text_pruner
from topicminer.utils.email_text_processing import process_emails_to_json, read_json_to_dataframe

# %% [markdown]
# # Text Pruning Widget

# %%
# Widget to view emails interactively and add unwanted texts to the json file. 

text_pruner = text_pruner()
display(text_pruner)
# Out:
# VBox(children=(HBox(children=(Button(description='Previous', style=ButtonStyle()), Label(value='Document 1 of …

# %% [markdown]
# # Read the email text files and process them into a JSON file.

# %%
process_emails_to_json(chunk_size=10, analyze_emails=True)
# Out:
# 100%|██████████| 502/502 [00:00<00:00, 718.43it/s]
#      Email Analysis Report
# ===============================
# Total Emails: 502
# Unique Senders: 11
# Unique Recipients: 317
#
# Attachment Analysis:
# ======================
# Emails with Attachments: 0
# Emails with Multiple Attachments: 0
#
# Recipient Analysis:
# =====================
# Emails with Multiple Recipients: 340
# Avg Recipient Count: 2.91
#
# Additional Statistics:
# ========================
# Avg Word Count: 124.89
# Avg Character Count: 750.4
# Avg Token Count: 70.94
#
# Category Analysis:
# ========================
# Emails with Multiple Categories: 0
# Unique Categories: 36
# Category Counts:
# ---------------
#   Personal Update: 9
#   Industry News: 28
#   Social Event: 19
#   Training and Development: 12
#   Technical Support: 15
#   Project Update: 21
#   Condolences: 14
#   Wellness Check: 18
#   Apology: 21
#   Event Planning: 12
#   Office Relocation: 7
#   Quality Assurance: 15
#   Expense Report: 21
#   Supplier Relations: 19
#   Thank You: 21
#   Congratulations: 19
#   Internal Announcement: 30
#   Meeting Request: 9
#   Press Release: 4
#   Vacation Notice: 25
#   Invitation: 17
#   System Outage: 11
#   Personal Milestone: 21
#   Partnership Proposal: 2
#   Health and Safety: 12
#   Compliance: 22
#   Volunteer Opportunities: 15
#   Reminder: 18
#   Research Collaboration: 10
#   HR Matters: 4
#   Invoice: 2
#   Marketing Campaign: 1
#   Sales Inquiry: 3
#   Product Launch: 21
#   Product Recall: 3
#   Contract Negotiation: 1

# %% [markdown]
# # View Processed Emails in a DataFrame

# %%
import pandas as pd
df = read_json_to_dataframe()
df.head(3)
