# %% [markdown]
# # Text Pruning and Processing Tutorial

# %%
# Required to display widgets in Jupyter
import os
import sys

#This will navigate up two levels in the directory structure to the root of your project
sys.path.append(os.path.dirname(os.getcwd()))

# Import to minimize warning. 
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

# Import the necessary widget handling libraries
from IPython.display import display
#import ipywidgets as widgets

# Import your custom widget
from topicminer.utils.widgets import text_pruner
from topicminer.utils.email_text_processing import process_emails_to_csv,process_emails_to_json
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 20
#      17 from topicminer.utils.widgets import text_pruner
#      18 from topicminer.utils.email_text_processing import process_emails_to_csv,process_emails_to_json
# ---> 20 from .config import (
#      21     RAW_DATA_DIR,
#      22     UNWANTED_TEXTS_FILE,
#      23     PROCESSED_DATA_DIR_CSV,
#      24     PROCESSED_DATA_DIR_JSON,
#      25 )
#
# ImportError: attempted relative import with no known parent package

# %% [markdown]
# # Text Pruning Widget

# %%
# Widget to view emails interactively and add unwanted texts to the json file. 

text_pruner = text_pruner()
display(text_pruner)
# Out:
# VBox(children=(HBox(children=(Button(description='Previous', style=ButtonStyle()), Label(value='Document 1 of …

# %% [markdown]
# # Text Preprocessing to CSV file

# %%
df_emails = process_emails_to_csv()
df_emails.head(2)
# Out:
# 100%|██████████| 75/75 [00:00<00:00, 622.72it/s]
#   doc_id             date   time day_of_week                            email_recipient                                    email_sender                                                                                        email_cc email_bcc                                               email_subject email_attachments               email_categories                                                                                                                                                                                                                                                                                                                                                                                                                                                      email_body  \
# 0   0005    June 02, 2024  08:47      Sunday  IT Support <itsupport@businessdomain.com>  Emily Turner <emily.turner@businessdomain.com>  John Doe <john.doe@businessdomain.com>; Customer Relations <cust.relations@businessdomain.com>    No BCC  Urgent: Repeated Login Failures Reported by Multiple Users    No Attachments                  No Categories                                         Hi Team,\nWe have received multiple reports this morning from users experiencing login failures despite correct credentials being entered. This issue seems to be escalating and affecting more of our customers.\nCan we have an immediate check on the server logs and possibly escalate this to the network team if necessary? We need a swift resolution to avoid further customer dissatisfaction.\nThanks,\nEmily
# 1   0043  August 08, 2025  08:30      Friday    HR Managers <hrmanagers@enterprise.com>         Angela Hughes <a.hughes@enterprise.com>                                                                                           No CC    No BCC                       Upcoming Employee Performance Reviews    No Attachments  HR Announcements, Performance  Hello Team,\nAs we approach the end of the fiscal year, it's time to start preparing for employee performance reviews. This is a crucial process to help us assess the progress and contributions of our staff over the past year. I will be sharing guidelines and timelines by the end of this week.\nLet's ensure that the reviews are conducted fairly and thoroughly to help our team grow and thrive.\nBest,\nAngela Hughes\nDirector of Human Resources
#
#                                                                                                                                                                                                                                                                                                       processed_text                                                           file_path
# 0         hi team we received multiple report morning user experiencing login failure despite correct credential entered this issue seems escalating affecting customer can immediate check server log possibly escalate network team necessary we need swift resolution avoid customer dissatisfaction thanks emily  /home/aaronnhorvitz/dev/work/irs/TopicMiner/data/raw_data/0005.txt
# 1  hello team as approach end fiscal year time start preparing employee performance review this crucial process help u ass progress contribution staff past year sharing guideline timeline end week let ensure review conducted fairly thoroughly help team grow thrive best angela hughes director human resources  /home/aaronnhorvitz/dev/work/irs/TopicMiner/data/raw_data/0043.txt

# %% [markdown]
# # Text Preprocessing to a JSON file.

# %%
process_emails_to_json()
# Out:
# 100%|██████████| 75/75 [00:00<00:00, 685.06it/s]

# %%
# Load the JSON data into a DataFrame
import pandas as pd

df_emails = pd.read_json(
    os.path.join(PROCESSED_DATA_DIR_JSON,'processed_emails.json')
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 STOP
#
# NameError: name 'STOP' is not defined

# %% [markdown]
# # LDA Topic Modeling

# %%
enriched_emails_df, lda_model_tfidf = tm.perform_lda_topic_modelling(
    df_emails,
    processed_text_col = 'processed_text', 
    num_topics=20,
    random_state=100,
    chunksize=100,
    passes=20,
    workers=20
)

# %%
dictionary, corpus = tm.prepare_corpus_and_dictionary(emails_df)

# %%
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis

# Assuming `lda_model` is your trained LDA model from Gensim and `corpus` and `id2word` are your corpus and dictionary
lda_visualization = gensimvis.prepare(lda_model_tfidf, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_visualization)
