# %% [markdown]
# # Text Pruning and Processing Tutorial

# %%
# Find parent directory and import path so topicminer correctly imports. 
import os
import sys
sys.path.append(os.path.dirname(os.getcwd()))  # Path to the parent directory

import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

import topicminer as tm
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 9
#       6 import warnings
#       7 warnings.filterwarnings('ignore', category=DeprecationWarning)
# ----> 9 import topicminer as tm
#
# File ~/dev/work/irs/TopicMiner/topicminer/__init__.py:2
#       1 # topicminer/__init__.py
# ----> 2 from .models import *
#       3 from .visualizations import *
#       4 from .utils import *
#
# File ~/dev/work/irs/TopicMiner/topicminer/models/__init__.py:13
#       1 """
#       2 Models Package for TopicMiner
#       3
#    (...)
#       9 or clustering models in the future.
#      10 """
#      12 # topicminer/models/__init__.py
# ---> 13 from .topic_models import *
#      14 from .classification_models import *
#
# File ~/dev/work/irs/TopicMiner/topicminer/models/topic_models/__init__.py:12
#       1 """
#       2 Topic Modeling Toolkit for TopicMiner
#       3
#    (...)
#       8 supports various methods of topic extraction and management, enhancing the analysis of unstructured text data.
#       9 """
#      11 from .doc2vec_kmeans import *
# ---> 12 from .lda_model import *
#
# File ~/dev/work/irs/TopicMiner/topicminer/models/topic_models/lda_model.py:14
#      10 import matplotlib.pyplot as plt
#      12 # Local application imports
#      13 #from topicminer import create_tfidf_corpus, prepare_corpus_and_dictionary
# ---> 14 from topicminer.utils.statistical_transforms import create_tfidf_corpus, prepare_corpus_and_dictionary
#      17 def train_lda_model(
#      18     emails_df: pd.DataFrame,
#      19     processed_text_col: str = "processed_text",
#    (...)
#      39     dtype: type = np.float32,
#      40 ) -> LdaMulticore:
#      41     """
#      42     Trains an LDA (Latent Dirichlet Allocation) model using the Gensim library with support for multicore processing.
#      43     It prepares the corpus and optionally applies TF-IDF transformation before training the model. This function is configured
#    (...)
#     100     >>> lda_model = train_lda_model(emails_df, 'processed_text', num_topics=5, passes=15, workers=4)
#     101     """
#
# File ~/dev/work/irs/TopicMiner/topicminer/utils/__init__.py:12
#      10 # topicminer/utils/__init__.py
#      11 from .email_text_processing import *
# ---> 12 from .widgets import *
#      13 from .statistical_transforms import *
#
# File ~/dev/work/irs/TopicMiner/topicminer/utils/widgets.py:87
#      84 from ..config import UNWANTED_TEXTS_FILE, RAW_DATA_DIR
#      86 # Use the imported path in your module
# ---> 87 with open(UNWANTED_TEXTS_FILE, 'r') as file:
#      88     data = json.load(file)
#      91 def email_viewer(
#      92     doc_id: str,
#      93     data_path: str,
#      94     unwanted_text_filepath: str = "./data/unwanted_texts/unwanted_texts.json",
#      95 ) -> str:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/aaronnhorvitz/dev/work/irs/TopicMiner/topicminer/config/data/unwanted_texts/unwanted_texts.json'

# %% [markdown]
# # Text Pruning Widget

# %%
#test_path = tm.utils.email_text_processing.load_unwanted_email_text(unwanted_texts_filepath=None)
test_path = tm.utils.verify_and_make_unwanted_texts_filepath(unwanted_texts_filepath=None)
test_path

# %%
# Widget to view emails interactively

text_pruner = tm.widgets.text_pruner()
display(text_pruner)

# %%
STOP

# %%
text_str = "From: Jane Doe Sent: Monday, May 26, 2024 9:15 AM To: Customer Support Subject: Inquiry About Product Discounts Hello, I was trying to navigate through your online portal and noticed several discounts for different products. However, I'm unsure about how to apply the member-exclusive discounts that are mentioned in the menu section. Could you guide me on how this works? Thanks, Jane"
test_text = tm.utils.email_text_processing.preprocess_text(text=text_str)
print(test_text)

# %% [markdown]
# # Text Preprocessing

# %%
df_emails = process_emails_in_directory(data_path, unwanted_text_path)

# %%
df_emails.head(5)

# %% [markdown]
# # LDA Topic Modeling

# %%
enriched_emails_df, lda_model_tfidf = tm.perform_lda_topic_modelling(
    df_emails,
    processed_text_col = 'processed_text', 
    num_topics=20,
    random_state=100,
    chunksize=100,
    passes=20,
    workers=20
)

# %%
dictionary, corpus = tm.prepare_corpus_and_dictionary(emails_df)

# %%
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis

# Assuming `lda_model` is your trained LDA model from Gensim and `corpus` and `id2word` are your corpus and dictionary
lda_visualization = gensimvis.prepare(lda_model_tfidf, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_visualization)
