# %%
#TODO: Topic - Add columnt for Top Topic = Just for a label. Column that corresponds to key terms.
#TODO: Kmeans terms next to LDA terms in an dataframe.   
#TODO: Build out the final bootstrap script. Outputs an Excel Spreadsheet all run from a .py file.
#TODO: Build out the repository

# %%
import sys
import os

# Get the current notebook's directory
src_path = os.path.dirname(os.getcwd())

# List of directories to append to sys.path
directories = ['topicminer', 'data', 'tests', 'notebooks', 'sandbox']

# Append each directory to sys.path
for directory in directories:
    path_to_append = os.path.join(src_path, directory)
    if os.path.exists(path_to_append):
        sys.path.append(path_to_append)
        print(f"Added {path_to_append} to sys.path")
    else:
        print(f"Directory {path_to_append} does not exist")

# Data Processing Operations
import pandas as pd

# Utilities for display
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import seaborn as sns

#Import Local Files
import tmbase as tm
import utils as ut
from utils import (
    read_text_file,
    parse_email_text_file_components,
    add_unwanted_text,
    load_unwanted_text,
    delete_unwanted_text,
    clean_email_body,
    preprocess_text,
    email_viewer,
    email_viewer_widget,
    process_emails_in_directory,
)
I usually use this when I display a pandas dataframe inside a jupyter notebook. However, it looks ugly in the cells.
Is it possible to put this in the .py file and use it to display a pandas dataframe within the notebook?

# Display Settings
pd.options.display.max_rows = 100       #Increases the number of rows displayed without a break in the middle.
pd.options.display.max_columns = 100    #Increases the number of columns displayed without a break in the middle.
pd.set_option('max_colwidth',500)      #Increases the width of the columns to display 2000 characters at the same time.

# Maximize Display Width
display(HTML("""

<style>
.container { width:75% !important; }
.text_cell_render { /* Class used for Markdown cells */
    max-width: none;
}
</style>
"""))
# Out:
# Added /home/aaronnhorvitz/dev/work/irs/TopicMiner/topicminer to sys.path
# Added /home/aaronnhorvitz/dev/work/irs/TopicMiner/data to sys.path
# Added /home/aaronnhorvitz/dev/work/irs/TopicMiner/tests to sys.path
# Added /home/aaronnhorvitz/dev/work/irs/TopicMiner/notebooks to sys.path
# Added /home/aaronnhorvitz/dev/work/irs/TopicMiner/sandbox to sys.path
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 28
#      25 import seaborn as sns
#      27 #Import Local Files
# ---> 28 import tmbase as tm
#      29 import utils as ut
#      30 from utils import (
#      31     read_text_file,
#      32     parse_email_text_file_components,
#    (...)
#      40     process_emails_in_directory,
#      41 )
#
# ModuleNotFoundError: No module named 'tmbase'

# %% [markdown]
# # Data Paths

# %%
data_path = os.path.join(src_path, 'data/processed') #Path to the data directory
unwanted_text_path = os.path.join(src_path, 'unwanted_text.json') #Path to the unwanted_text.json file

# %% [markdown]
# # Text Pruning Widget

# %%
# Widget to view emails interactively

email_widget = ut.email_viewer_widget(
    data_path, 
    unwanted_text_path
    )
display(email_widget)
# Out:
# VBox(children=(HBox(children=(VBox(children=(HBox(children=(Text(value='', description='Go to ID:', placeholde…

# %% [markdown]
# # Text Preprocessing

# %%
df_emails = process_emails_in_directory(data_path, unwanted_text_path)
# Out:
# 100%|██████████| 35572/35572 [01:13<00:00, 483.19it/s]

# %%
df_emails.head(5)
# Out:
#       doc_id     date     time day_of_week       to_line  \
# 0  C05739545  Unknown  Unknown     Unknown             H
# 1  C05739546  Unknown  Unknown     Unknown             H
# 2  C05739547  Unknown  Unknown     Unknown            ;H
# 3  C05739550  Unknown  Unknown     Unknown             H
# 4  C05739554  Unknown  Unknown     Unknown  Abedin, Huma
#
#                                                                                     from_line  \
# 0                                                                           Sullivan, Jacob J
# 1  Sid Re: Syria aiding Qaddafi This memo has two parts. Part one is the report that Syria is
# 2                                                                             Mills, Cheryl D
# 3                                                                             Mills, Cheryl D
# 4                                                                                           H
#
#                                                 subj_line  \
# 0                                                     WOW
# 1  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MORE... SID
# 2                                           CHRIS STEVENS
# 3                              CAIRO CONDEMNATION - FINAL
# 4  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MORE... SID
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             email_body  \
# 0  UNCLASSIFIED U.S. Department of State Case No. F-2015-04841 Doc No. C05739545 Date: 05/13/2015 STATE\nDEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION &\nREDACTIONS. NO FOIA WAIVER. RELEASE IN FULL From: (cid:9)Sullivan, Jacob J <Sullivan11@state.gov>\nChristian (Armed Services) (mailto:Christian_Brose@armed-servic,essenate.govi  Sent: Wednesday,\nSeptember 12, 2012 10:09 AM To: Sullivan, Jacob J Subject: Wow What a wonderful, strong and moving\ns...
# 1  UNCLASSIFIED U.S. Department of State Case No. F-2015-04841 Doc No. C05739546 Date: 05/13/2015 STATE\nDEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION &\nREDACTIONS. NO FOIA WAIVER.   RELEASE IN PART B6 From: Sent: To: Subject: Attachments:  B6 Thursday,\nMarch 3, 2011 9:45 PM H: Latest How Syria is aiding Qaddafi and more... Sid hrc memo syria aiding\nlibya 030311.docx; hrc memo syria aiding libya 030311.docx  CONFIDENTIAL March 3, 2011 For: Hill...
# 2  UNCLASSIFIED U.S. Department of State Case No. F-2015-04841 Doc No. C05739547 Date: 05/14/2015 STATE\nDEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION &\nREDACTIONS. NO FOIA WAIVER. RELEASE IN PART B6 From: (cid:9)Mills, Cheryl D <MillsCD@state.gov>\n(cid:9)Re: Chris Stevens Thx (cid:9)Original Message (cid:9) From: Anne-Marie Slaughter [ Sent:\nWednesday, September 12, 2012 07:46 AM To: Ihdr22@clintonernail.com' <hdr22@clintonemail  corn> Cc:\nAb...
# 3  UNCLASSIFIED U.S. Department of State Case No. F-2015-04841 Doc No. C05739550 Date: 05/13/2015 STATE\nDEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION &\nREDACTIONS. NO FOIA WAIVER. RELEASE IN PART B5 From: (cid:9)Mills, Cheryl D <MillsCD@state.gov>\nFinal From: Smith, Dana S (PA) Sent: Wednesday, September 12, 2012 11:53 AM To Mills, Cheryl D\nSubject FW: Cairo Condemnation - Final B5 From: Snipe, Aaron D Sent: Tuesday, September 11 2012 1:31\nPM...
# 4  B6 UNCLASSIFIED U.S. Department of State Case No. F-2015-04841 Doc No. C05739554 Date: 05/13/2015\nSTATE DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION\n& REDACTIONS. NO FOIA WAIVER. RELEASE IN PART B6 From: Sent: To: Subject: Attachments: H\n<hrod17@clintonemail.com> Friday, March 11, 2011 1:36 PM Huma Abedin Fw: H: Latest: How Syria is\naiding Qaddafi and more... Sid hrc memo syria aiding libya 030311.docx Pis print. From: Sent:\nThursday, Mar...
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         processed_text  \
# 0  doc date state dept produced house select benghazi comm subject agreement sensitive information redaction foia waiver release full cidsullivan jacob sullivanstategov christian armed service mailtochristianbrosearmedservicessenategovi sent wednesday september sullivan jacob subject wow wonderful strong moving statement bos please tell much sen mccain appreciated unclassified u department state case doc date state dept produced house select benghazi comm subject agreement sensitive information...
# 1  doc date state dept produced house select benghazi comm subject agreement sensitive information redaction foia waiver release part sent subject attachment thursday march pm latest syria aiding qaddafi sid hrc memo syria aiding libya docx hrc memo syria aiding libya docx confidential march hillary providing air support qaddafi part two note cody lord david owen former uk foreign secretary view increasingly complex crisis seems situation developing protracted civil war various nation backing o...
# 2  doc date state dept produced house select benghazi comm subject agreement sensitive information redaction foia waiver release part cidmills cheryl millscdstategov cidre chris stevens thx cidoriginal message cid annemarie slaughter sent wednesday september ihdrclintonernailcom hdrclintonemail corn cc abed huma mill cheryl subject chris stevens former colleague im terribly sorry fsos stand front line surely devotedly soldier thinking pat everyone morning unclassified u department state case do...
# 3  doc date state dept produced house select benghazi comm subject agreement sensitive information redaction foia waiver release part cidmills cheryl millscdstategov final smith dana pa sent wednesday september mill cheryl subject fw cairo condemnation final snipe aaron sent tuesday september pm smith dana pa subject fw cairo condemnation final fyi snipe aaron sent tuesday september schwartz larry ranz david sievers marc linfield david sayles ambrose neapressdl neaegypt shea peter cc mitchell a...
# 4  doc date state dept produced house select benghazi comm subject agreement sensitive information redaction foia waiver release part sent subject attachment hrodclintonemailcom friday march pm huma abedin fw latest syria aiding qaddafi sid hrc memo syria aiding libya docx pi print sent thursday march pm subject latest syria aiding qaddafi sid confidential march hillary sid syria aiding qaddafi memo two part part one report syria providing air support qaddafi part two note cody lord david owen ...
#
#                                                     file_path
# 0  c:\Users\aaron\dev\TopicMiner\data/processed\C05739545.txt
# 1  c:\Users\aaron\dev\TopicMiner\data/processed\C05739546.txt
# 2  c:\Users\aaron\dev\TopicMiner\data/processed\C05739547.txt
# 3  c:\Users\aaron\dev\TopicMiner\data/processed\C05739550.txt
# 4  c:\Users\aaron\dev\TopicMiner\data/processed\C05739554.txt

# %% [markdown]
# # LDA Topic Modeling

# %%
enriched_emails_df, lda_model_tfidf = tm.perform_lda_topic_modelling(
    df_emails,
    processed_text_col = 'processed_text', 
    num_topics=20,
    random_state=100,
    chunksize=100,
    passes=20,
    workers=20
)
# Out:
# The maximum number of workers allowed is 8. Setting workers to 8.
# Training LDA Model: 100%|██████████| 19/19 [06:02<00:00, 19.06s/it]

# %%
dictionary, corpus = tm.prepare_corpus_and_dictionary(emails_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dictionary, corpus = tm.prepare_corpus_and_dictionary(emails_df)
#
# NameError: name 'emails_df' is not defined

# %%
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis

# Assuming `lda_model` is your trained LDA model from Gensim and `corpus` and `id2word` are your corpus and dictionary
lda_visualization = gensimvis.prepare(lda_model_tfidf, corpus, dictionary, sort_topics=False)
pyLDAvis.display(lda_visualization)
