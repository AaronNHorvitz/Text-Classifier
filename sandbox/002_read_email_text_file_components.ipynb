# %%
import sys
sys.path.append('C:/Users/aaron/dev/TopicMiner/')

# %%
import pandas as pd


from topicminer.utils import (
    read_text_file, 
    parse_email_text_file_components, 
    add_unwanted_text, 
    load_unwanted_text,
    delete_unwanted_text, 
    clean_email_body,
    preprocess_text, 
    email_viewer, 
    email_viewer_widget, 
    process_emails_in_directory, 
)

# %%
unwanted_text_file_path = 'C:/Users/aaron/dev/TopicMiner/data/hrc/unwanted_text/unwanted_text.json'
example_text_file_path = 'C:/Users/aaron/dev/TopicMiner/data/hrc/processed/C06245079.txt'

# %% [markdown]
# # View a specific email

# %%
text_file_path = 'C:/Users/aaron/dev/TopicMiner/data/hrc/processed/C05739545.txt'
text_file_contents = read_text_file(text_file_path)

# Join to '' in order for line returns to line up properly in print. 
print(''.join(text_file_contents))
# Out:
# To: H
# From: Sullivan, Jacob J
# Sent: September 12, 2012
# Subject: WOW
#
# UNCLASSIFIED U.S. Department of State Case No. F-2015-04841 Doc No. C05739545 Date: 05/13/2015 STATE
# DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION &
# REDACTIONS. NO FOIA WAIVER. RELEASE IN FULL From: (cid:9)Sullivan, Jacob J <Sullivan11@state.gov>
# Sent: (cid:9)Wednesday, September 12, 2012 10:16 AM To: Subject: (cid:9)FW: Wow From: Brose,
# Christian (Armed Services) (mailto:Christian_Brose@armed-servic,essenate.govi  Sent: Wednesday,
# September 12, 2012 10:09 AM To: Sullivan, Jacob J Subject: Wow What a wonderful, strong and moving
# statement by your boss. please tell her how much Sen. McCain appreciated it. Me too UNCLASSIFIED
# U.S. Department of State Case No. F-2015-04841 Doc No. C05739545 Date: 05/13/2015 STATE DEPT. -
# PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS.
# NO FOIA WAIVER. (cid:9)STATE-5CB0045247

# %% [markdown]
# # Break apart the email components and view the email body.

# %%
email_recipient, email_from, email_date, email_subject, email_body =  parse_email_text_file_components(text_file_contents)
print(''.join(email_body)) # join to '' in order for line returns to line up properly in print.
# Out:
# UNCLASSIFIED U.S. Department of State Case No. F-2015-04841 Doc No. C05739545 Date: 05/13/2015 STATE
# DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION &
# REDACTIONS. NO FOIA WAIVER. RELEASE IN FULL From: (cid:9)Sullivan, Jacob J <Sullivan11@state.gov>
# Christian (Armed Services) (mailto:Christian_Brose@armed-servic,essenate.govi  Sent: Wednesday,
# September 12, 2012 10:09 AM To: Sullivan, Jacob J Subject: Wow What a wonderful, strong and moving
# statement by your boss. please tell her how much Sen. McCain appreciated it. Me too UNCLASSIFIED
# U.S. Department of State Case No. F-2015-04841 Doc No. C05739545 Date: 05/13/2015 STATE DEPT. -
# PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS.
# NO FOIA WAIVER. (cid:9)STATE-5CB0045247

# %% [markdown]
# # Add strings of texts to the unwanted text and view the list of unwanted texts.

# %%
# Add unwanted text. 
add_unwanted_text(unwanted_text_file_path, 'PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS.')
add_unwanted_text(unwanted_text_file_path, 'PRODUCED TO HOUSE SELECT BENGHAZI COMM')
add_unwanted_text(unwanted_text_file_path, 'SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION')
# Out:
# Text added successfully.
# Text added successfully.
# Text added successfully.

# %% [markdown]
# # View the list of unwanted texts

# %%
load_unwanted_text(unwanted_text_file_path)
# Out:
# ['PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS.',
#  'SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION',
#  'UNCLASSIFIED',
#  'DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM. ',
#  'REDACTIONS. NO FOIA WAIVER. RELEASE IN FULL',
#  'U.S. Department of State Case No. F-2015-04841 Doc No. C05739545 Date: 05/13/2015 STATE DEPT. -',
#  'NO FOIA WAIVER',
#  '(cid:9)STATE-5CB0045247',
#  'U.S. Department of State Case No. F-2015-04841 Doc No. C05739545',
#  'REDACTIONS',
#  'STATE SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION',
#  'AGREEMENT ON SENSITIVE INFORMATION',
#  'STATE',
#  'STATE-SCB0045002',
#  'UNCLASSIFI',
#  'CONFIDENTIAL',
#  'U.S. Department of State Case No. F-2015-04841 Doc No. C05739561',
#  'RELEASE IN PART B6',
#  'RELEASE IN PART B5',
#  'PRODUCED TO HOUSE SELECT BENGHAZI COMM']

# %% [markdown]
# # Delete an item of unwanted text from the list

# %%
delete_unwanted_text(unwanted_text_file_path, 'PRODUCED TO HOUSE SELECT BENGHAZI COMM')
# Out:
# Text removed successfully.

# %%
# View the list after the deletion 
load_unwanted_text(unwanted_text_file_path)
# Out:
# ['PRODUCED TO HOUSE SELECT BENGHAZI COMM. SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS.',
#  'SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION',
#  'UNCLASSIFIED',
#  'DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM. ',
#  'REDACTIONS. NO FOIA WAIVER. RELEASE IN FULL',
#  'U.S. Department of State Case No. F-2015-04841 Doc No. C05739545 Date: 05/13/2015 STATE DEPT. -',
#  'NO FOIA WAIVER',
#  '(cid:9)STATE-5CB0045247',
#  'U.S. Department of State Case No. F-2015-04841 Doc No. C05739545',
#  'REDACTIONS',
#  'STATE SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION',
#  'AGREEMENT ON SENSITIVE INFORMATION',
#  'STATE',
#  'STATE-SCB0045002',
#  'UNCLASSIFI',
#  'CONFIDENTIAL',
#  'U.S. Department of State Case No. F-2015-04841 Doc No. C05739561',
#  'RELEASE IN PART B6',
#  'RELEASE IN PART B5']

# %% [markdown]
# # Preprocess Text

# %%
processed_text = preprocess_text(email_body, unwanted_text_file_path)

# Join to '' in order for line returns to line up properly in print. 
print(''.join(processed_text))
# Out:
# date cidsullivan jacob sullivanstategov christian armed service mailtochristianbrosearmedservicessenategovi sent wednesday september sullivan jacob subject wow wonderful strong moving statement bos please tell much sen mccain appreciated

# %% [markdown]
# # Widget Builder

# %%
# Example usage:
unwanted_text_file_path = 'C:/Users/aaron/dev/TopicMiner/data/hrc/unwanted_text/unwanted_text.json'
data_path = 'C:/Users/aaron/dev/TopicMiner/data/hrc/processed/'
doc_id = 'C05739545'
email_viewer(doc_id, data_path, unwanted_text_file_path)
# Out:
# '\n        <style>\n            table { width: 100%; border-collapse: collapse; }\n            th, td { border: 1px solid #ddd; padding: 8px; vertical-align: top; }  /* Ensure content is top-aligned */\n            th { background-color: #f2f2f2; }\n            pre { white-space: pre-wrap; word-wrap: break-word; text-align: left; margin: 0; max-width: 600px; font-family: \'Arial\', sans-serif; font-size: 14px; }\n            mark { background-color: orange; }\n            .text-container { text-align: left; overflow-wrap: break-word; min-height: 400px; }  /* Adjusted for more vertical space */\n        </style>\n        <table>\n            <tr>\n                <th>Original Email (Highlighted Unwanted Text)</th>\n                <th>Removed Unwanted Text</th>\n                <th>Normalized Text</th>\n            </tr>\n            <tr>\n                <td><div class="text-container"><pre>To: H\nFrom: Sullivan, Jacob J\nSent: (cid:9)Wednesday, September 12, 2012 10:16 AM To: Subject: (cid:9)FW: Wow From: Brose,\n\nSubject: WOW\n\n<mark style=\'background-color: orange;\'><mark style=\'background-color: orange;\'>UNCLASSIFI</mark>ED</mark> <mark style=\'background-color: orange;\'>U.S. Department of State Case No. F-2015-04841 Doc No. C05739545</mark> Date: 05/13/2015 <mark style=\'background-color: orange;\'>STATE</mark>\n<mark style=\'background-color: orange;\'>DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM. </mark><mark style=\'background-color: orange;\'>SUBJECT TO <mark style=\'background-color: orange;\'>AGREEMENT ON SENSITIVE INFORMATION</mark></mark> &\n<mark style=\'background-color: orange;\'><mark style=\'background-color: orange;\'>REDACTIONS</mark>. <mark style=\'background-color: orange;\'>NO FOIA WAIVER</mark>. RELEASE IN FULL</mark> From: (cid:9)Sullivan, Jacob J <Sullivan11@state.gov>\nChristian (Armed Services) (mailto:Christian_Brose@armed-servic,essenate.govi  Sent: Wednesday,\nSeptember 12, 2012 10:09 AM To: Sullivan, Jacob J Subject: Wow What a wonderful, strong and moving\nstatement by your boss. please tell her how much Sen. McCain appreciated it. Me too <mark style=\'background-color: orange;\'><mark style=\'background-color: orange;\'>UNCLASSIFI</mark>ED</mark>\n<mark style=\'background-color: orange;\'><mark style=\'background-color: orange;\'>U.S. Department of State Case No. F-2015-04841 Doc No. C05739545</mark> Date: 05/13/2015 <mark style=\'background-color: orange;\'>STATE</mark> DEPT. -</mark>\n<mark style=\'background-color: orange;\'>PRODUCED TO HOUSE SELECT BENGHAZI COMM. <mark style=\'background-color: orange;\'>SUBJECT TO <mark style=\'background-color: orange;\'>AGREEMENT ON SENSITIVE INFORMATION</mark></mark> & <mark style=\'background-color: orange;\'>REDACTIONS</mark>.</mark>\n<mark style=\'background-color: orange;\'>NO FOIA WAIVER</mark>. <mark style=\'background-color: orange;\'>(cid:9)<mark style=\'background-color: orange;\'>STATE</mark>-5CB0045247</mark></pre></div></td>\n                <td><div class="text-container"><pre>To: H\nFrom: Sullivan, Jacob J\nSent: (cid:9)Wednesday, September 12, 2012 10:16 AM To: Subject: (cid:9)FW: Wow From: Brose,\n\nSubject: WOW\n\n  Date: 05/13/2015 \n &\n From: (cid:9)Sullivan, Jacob J <Sullivan11@state.gov>\nChristian (Armed Services) (mailto:Christian_Brose@armed-servic,essenate.govi  Sent: Wednesday,\nSeptember 12, 2012 10:09 AM To: Sullivan, Jacob J Subject: Wow What a wonderful, strong and moving\nstatement by your boss. please tell her how much Sen. McCain appreciated it. Me too \n\n\n. </pre></div></td>\n                <td><div class="text-container"><pre>date cidsullivan jacob sullivanstategov christian armed service mailtochristianbrosearmedservicessenategovi sent wednesday september sullivan jacob subject wow wonderful strong moving statement bos please tell much sen mccain appreciated</pre></div></td>\n            </tr>\n        </table>\n        '

# %%
# Widget to view emails interactively
email_widget = email_viewer_widget(data_path, unwanted_text_file_path)
display(email_widget)
# Out:
# VBox(children=(HBox(children=(VBox(children=(HBox(children=(Text(value='', description='Go to ID:', placeholde…

# %% [markdown]
# # Build the Modeling DataFrame

# %%
df_emails = process_emails_in_directory(data_path, unwanted_text_file_path)
# Out:
#  82%|█████████████████████████████████████████████████████████████▏             | 29035/35571 [01:05<00:17, 383.94it/s]
