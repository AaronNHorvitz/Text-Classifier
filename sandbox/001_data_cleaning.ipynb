# %% [markdown]
# # Convert all text in the original emails to text files.

# %%
import pandas as pd
import sys
sys.path.append('C:/Users/aaron/dev/TopicMiner/')

# %%
pwd()
# Out:
# 'C:\\Users\\aaron\\dev\\TopicMiner\\sandbox'

# %%
data_file = 'C:/Users/aaron/dev/TopicMiner/data/raw/hillary_clinton/data.csv'

# %%
df = pd.read_csv(data_file)

# %%
pwd()
# Out:
# 'C:\\Users\\aaron\\dev\\TopicMiner\\sandbox'
